# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels

tab = np.random.rand(6, 2)

colonnes = ['a', 'b']
lignes = ['1', '2', '3', '4',  '5', '6']


# Créer un DataFrame avec ces noms
df = pd.DataFrame(tab, columns=colonnes, index=lignes)

print(df)
# Out:
#           a         b
# 1  0.260740  0.736017
# 2  0.988102  0.863873
# 3  0.808517  0.497844
# 4  0.903640  0.669532
# 5  0.203211  0.114815
# 6  0.766371  0.385075

# %%
mean_a = df['a'].mean()
mean_b = df['b'].mean()

# %%
x= df['a']
y = df['b']
